# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
from ridge_map.ridge_map import RidgeMap

m = RidgeMap().plot_map()
# Out:
# /Users/marcin.cylke/Virtualenvs/py3/lib/python3.6/site-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %%
# !cat x
# Out:
# 22.214184,49.420689,22.337093,49.459310

# %%
rm = RidgeMap((22.214184,49.420689,22.337093,49.459310))
values = rm.get_elevation_data(num_lines=40)
values=rm.preprocess(
    values=values,
    lake_flatness=2,
    water_ntile=10,
    vertical_ratio=240)
rm.plot_map(values=values,
            label='Karwendelgebirge',
            label_y=0.1,
            label_x=0.55,
            label_size=40,
            linewidth=1)
# Out:
# /Users/marcin.cylke/Virtualenvs/py3/lib/python3.6/site-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
